# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
land_map = np.array([
    [1,1,1,2,2,2],
    [1,1,2,2,2,2],
    [1,3,3,2,2,2],
    [3,3,3,4,4,4],
    [3,3,4,4,4,4],
    [3,4,4,4,4,4]
])

land_map
# Out:
# array([[1, 1, 1, 2, 2, 2],
#        [1, 1, 2, 2, 2, 2],
#        [1, 3, 3, 2, 2, 2],
#        [3, 3, 3, 4, 4, 4],
#        [3, 3, 4, 4, 4, 4],
#        [3, 4, 4, 4, 4, 4]])

# %%
plt.imshow(land_map)
plt.colourbar()
plt.title("GeoSnap Land Use Map")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 2
#       1 plt.imshow(land_map)
# ----> 2 plt.colourbar()
#       3 plt.title("GeoSnap Land Use Map")
#       4 plt.show()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'colourbar'
