# %%
import pandas as pd

data = {
    "Blue" : [30,60,20,90,50,80,25,95],
    "Green" : [40,70,30,100,60,90,35,105],
    "Red" : [25,110,45,120,30,100,35,115],
    "NIR" : [120,90,150,80,180,85,160,70],
    "Class" : [
        "Forest",
        "Urban",
        "Forest",
        "Urban",
        "Forest",
        "Urban",
        "Forest",
        "Urban"
    ]
}

df = pd.DataFrame(data)

df
# Out:
#    Blue  Green  Red  NIR   Class
# 0    30     40   25  120  Forest
# 1    60     70  110   90   Urban
# 2    20     30   45  150  Forest
# 3    90    100  120   80   Urban
# 4    50     60   30  180  Forest
# 5    80     90  100   85   Urban
# 6    25     35   35  160  Forest
# 7    95    105  115   70   Urban

# %%
from sklearn.model_selection import train_test_split

x = df[["Blue","Green","Red","NIR"]]
y = df["Class"]

x_train,x_test,y_train,y_test = train_test_split(
    x,y,test_size = 0.2,random_state = 42
)

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier()
model.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
predictions = model.predict(x_test)
print(predictions)
# Out:
# ['Urban' 'Urban']

# %%
from sklearn.metrics import accuracy_score

accuracy = accuracy_score(y_test,predictions)

print("Accuracy :",accuracy)
# Out:
# Accuracy : 1.0

# %%
import matplotlib.pyplot as plt
bands = ["Blue","Green","Red","NIR"]
importance = model.feature_importances_

plt.bar(bands,importance)
plt.title("Feature Importance")
plt.ylabel("Importance")
plt.show()
